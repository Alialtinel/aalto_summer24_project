# %% [markdown]
# <a href="https://colab.research.google.com/github/Alialtinel/aalto_summer24_project/blob/main/notebooks/descriptive_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import userdata
access_token = userdata.get('pat_key')

# %%
# !git clone https://{acces_token}@github.com/Alialtinel/aalto_summer24_project.git
# Out:
# Cloning into 'aalto_summer24_project'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 119 (delta 39), reused 40 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 3.38 MiB | 15.79 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
# %cd aalto_summer24_project
# Out:
# /content/aalto_summer24_project

# %%
df_2015 = pd.read_excel('/content/aalto_summer24_project/data/french_poverty_urban_areas_2015.xlsx')
df_2016 = pd.read_excel('/content/aalto_summer24_project/data/french_poverty_urban_areas_2016.xlsx')
df_2017 = pd.read_excel('/content/aalto_summer24_project/data/french_poverty_urban_areas_2017.xlsx')

# %%
import plotly.express as px

# 2015
corr_matrix_2015 = df_2015.select_dtypes(include='number').corr()
fig_2015 = px.imshow(corr_matrix_2015,
                    color_continuous_scale='RdBu',
                    title='Correlation Heatmap 2015')
fig_2015.show()

# 2016
corr_matrix_2016 = df_2016.select_dtypes(include='number').corr()
fig_2016 = px.imshow(corr_matrix_2016,
                    color_continuous_scale='RdBu',
                    title='Correlation Heatmap 2016')
fig_2016.show()

# 2017
corr_matrix_2017 = df_2017.select_dtypes(include='number').corr()
fig_2017 = px.imshow(corr_matrix_2017,
                    color_continuous_scale='RdBu',
                    title='Correlation Heatmap 2017')
fig_2017.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 2015
fig_2015 = px.scatter(df_2015, x="RD", y="PPLOGT",
                     trendline="ols",
                     title='PPLOGT vs. RD 2015')
fig_2015.show()

# 2016
fig_2016 = px.scatter(df_2016, x="RD", y="PPLOGT",
                     trendline="ols",
                     title='PPLOGT vs. RD 2016')
fig_2016.show()

# 2017
fig_2017 = px.scatter(df_2017, x="RD", y="PPLOGT",
                     trendline="ols",
                     title='PPLOGT vs. RD 2017')
fig_2017.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
